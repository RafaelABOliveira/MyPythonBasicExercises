# %%
print('First Program')
1 \
+ 2

help(print)
# Out:
# First Program
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
1 + 2 + 3
# Out:
# 6

# %%
print (1 + 2 + 3)
print (3 + 3 + 3)
# Out:
# 6
# 9

# %%
# Basics Types

# %%
print ('You are ' + 3 * 'very ' + 'cool')
print (None)
# Out:
# You are very very very cool
# None

# %% [markdown]
# # Variables

# %%
a = 10
b = 5.2

print (a + b)

a = 'Im a String now'
print(a)
# Out:
# 15.2
# Im a String now

# %% [markdown]
# # Comments

# %%
# comments

# %%
salario = 5000
despesas = 2560

#make calc

'''
a idéia é comentar
'''

print(salario - despesas)
# Out:
# 2440

# %% [markdown]
# # Arithmetics Operators

# %%
print(2 + 3)
print(4 - 7)
print(3 * 4.6)
print(3.3 / 2.9)
print(3.3 // 2.9) #obrigado a ser um número inteiro
print(9 ** 5) #elevate

a = 12
b = a

print(a + b)
# Out:
# 5
# -3
# 13.799999999999999
# 1.1379310344827587
# 1.0
# 59049
# 24

# %% [markdown]
# # My variables
#
# salary = 5000.32
# expenses = 2567.56
#
# #calc
# commited_percentage = expenses / salary * 100
# commited_percentage

# %% [markdown]
# # Relational Operators

# %%
2 == '2' #JS is true but in Python is false
# Out:
# False

# %% [markdown]
# # Assingment Operators

# %%
a = 3
a = a + 7
print (a)

a += 5
print(a)
a *= 3
print(a)
a /= 4
print (a)
a %= 4
print(a)
a **= 5
print(a)
# Out:
# 10
# 15
# 45
# 11.25
# 3.25
# 362.5908203125

# %% [markdown]
# # Logical Operators

# %%
True and False
7 != 3 and 2>3

True or False
7 != 3 and 2>3

#Real Structure
saldo = 1000
salario = 4000
despesas = 3900

saldo_positivo = saldo > 0
despesas_controladas = salario - despesas >= 0.2 * salario

meta = saldo_positivo and despesas_controladas
meta
# Out:
# False

# %%
#Logical Operators

trabalho_terca = True
trabalho_quinta = False

"""
Comfirmando os 2: TV 50' + Sorvete
Confirmando apenas 1: TV 32' + Sorvete
Nenhum Confirmado: Fica em casa
"""

tv_50 = trabalho_terca and trabalho_quinta
sorvete = trabalho_terca or trabalho_quinta
tv_32 = trabalho_terca != trabalho_quinta
mais_saudavel = not sorvete

print('Tv50={} Tv32={} Sorvete={} Saudável={}'
     .format (tv_50, tv_32, sorvete, mais_saudavel))

"{2}, {0} = {1}".format(1, False, 'resultado') #choose sequence
"{}, {} = {}".format(1, False, 'resultado') #logical sequence
# Out:
# Tv50=False Tv32=True Sorvete=True Saudável=False
# '1, False = resultado'

# %% [markdown]
# # Unary operators

# %%
a = 3
++a
++a
-a
+a
# Out:
# 3

# %% [markdown]
# # Ternary Operators

# %%
esta_chuvendo = True
print('Hoje estou com as roupas ' + ('secas.', 'molhadas.')[esta_chuvendo])

print('Hoje estou com as roupas ' + ('molhadas.' if esta_chuvendo else 'secas.'))
# Out:
# Hoje estou com as roupas molhadas.
# Hoje estou com as roupas molhadas.

# %%
x = 3
y = x
z = 3
x is y
y is z
x is not y

lista_a = [1, 2, 3]
lista_b = lista_a
lista_c = [1, 2, 3]

lista_a is lista_b
lista_a is not lista_c
# Out:
# True

# %% [markdown]
# # Builtins

# %%
type(1)
__builtins__.type('Fala Galera!')
__builtins__.print(10 / 3)

# help(dir)

dir()

1 + 2

dir(__builtins__)

nome = 'João da Silva'
type(nome)
__builtins__.len(nome)
# Out:
# 3.3333333333333335
# 13

# %% [markdown]
# # Convert Types

# %%
2 + 3
'2' + '3'


a = 2
b = '3'

print(type(a))
print(type(b))

print(a + int(b))
print(str(a) + b)

type(str(a))
# Out:
# <class 'int'>
# <class 'str'>
# 5
# 23
# str

# %% [markdown]
# # Automatic Coercion

# %%
10 / 2
10 // 3 #obriga o resultado ser inteiro
type(1 + 2)
type(1.1 + 3)
# Out:
# float

# %% [markdown]
# # Numeric types

# %%
dir(int)
dir(float)

int.__add__(2, 3)
# Out:
# 5

# %% [markdown]
# # Decimal (precision)

# %%
from decimal import Decimal, getcontext
Decimal(1)/ Decimal(7)

getcontext().prec = 4 #precisão de número
Decimal (1) / Decimal (7)
Decimal.max(Decimal(1), Decimal(7))

dir(Decimal)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__complex__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'adjusted',
#  'as_integer_ratio',
#  'as_tuple',
#  'canonical',
#  'compare',
#  'compare_signal',
#  'compare_total',
#  'compare_total_mag',
# ...

# %% [markdown]
# # Strings

# %%
dir(str)
nome = 'Saulo Pedro'
nome
nome [0] #Give first letter of the name

"Dias D'Avila" == 'Dias D\ Avila'

texto = 'Texto entre apostrófos pode ter "aspas"'
texto

doc = """Texto
... com multiplas linhas"""
doc

print('Texto\n... com multiplas linhas')
print(doc)
# Out:
# Texto
# ... com multiplas linhas
# Texto
# ... com multiplas linhas

# %%
nome = 'Ana Paula'
nome[6]
nome[-3] #contará da direita para a esquerda
nome[3:] #range que eu quero selecionar
nome[:3] #range que quero ignorar
nome[2:5] #range entre um e outro

numeros = '0123456789'
numeros[::]
numeros[::2] #pula-rá de 2 em 2
# Out:
# '02468'

# %%
frase = 'Python is a amazing lenguage'
'py' not in frase
'ing' in frase
len(frase) #tamanho da frase
frase.lower() #diminui letras
frase
frase.upper() #aumenta letras
# Out:
# 'PYTHON IS A AMAZING LENGUAGE'

# %% [markdown]
# # Lists

# %%
lista = []
type(lista)
dir(lista)
#help(list)
len(lista) #tamanho de algo
lista.append(1) #adicionar algo na lista
lista.append(5) 
lista
lista.append([1,2,3])

nova_lista = [1, 5, 'Ana', 'Bia']
nova_lista
nova_lista.remove(5) #remove algo da lista (número 5 nesse caso)
nova_lista
nova_lista.reverse() #reverte a ordem da lista
print(nova_lista)
print(lista)
# Out:
# ['Bia', 'Ana', 1]
# [1, 5, [1, 2, 3]]

# %%
lista = [1, 5, 'Rebeca', 'Guilherme', 3.1415]
lista.index('Guilherme') #posição do elemento
#lista.index(3) #ele dá erro se não existe algo na lista
lista[2]
1 in lista
'Rebeca' in lista
'Pedro' not in lista 
lista[4]
lista[-5] #da direita para esquerda (começa do 1 nesse caso)
# Out:
# 1

# %%
lista = ['Ana', 'Lia', 'Rui', 'Paulo', 'Dani']
lista[1:3]
lista[1:-1] #range que quero selicionar
# Out:
# ['Lia', 'Rui', 'Paulo']

# %% [markdown]
# # Tuples

# %%
tupla = tuple()
tupla = ()
type(tupla)
dir(tupla)

tupla = ('um')
type(tupla)

cores = ('ver', 'vermelho' , 'amarelo', 'azul')
cores[-1]

cores.index('amarelo')
# Out:
# 2

# %% [markdown]
# # Dictionary

# %%
pessoa = {'nome': 'Prof(a).Ana', 'idade':38, 'cursos': ['Inglês', 'Português']}
type(pessoa)
# Out:
# dict

# %%
pessoa = {'nome': 'Prof(a).Alberto', 'idade':38, 'cursos': ['Inglês', 'Português']}
pessoa ['idade'] = 44 #altera o valor
pessoa
pessoa.pop('idade') #mostra apenas o valor

pessoa
pessoa.update({'idade':40, 'Sexo': 'M'})
pessoa
del pessoa['cursos'] #delete
pessoa
pessoa.clear() #limpa o dicionário
pessoa
# Out:
# {}

# %% [markdown]
# # Conjunto

# %%
a = {1, 2, 3}
type(a)
a = set('coddd3r') #não aceita repetição 'd'
print(a)
print('3' in a, 4 not in a)
{1, 2, 3} == {3, 2, 1, 3}

#operações
c1 = {1, 2}
c2 = {2, 3}
print(c1.union(c2))
print(c1.intersection(c2))
c1.update(c2) #junta os elementos (atualiza)
c1
c2 <= c1
c1 >= c2
c1
# Out:
# {'o', 'd', 'r', '3', 'c'}
# True True
# {1, 2, 3}
# {2}
# {1, 2, 3}

# %% [markdown]
# # Interpolation

# %%
nome, idade = 'Giovana', 30.9875

print('Nome: %s, Idade:%.2f' % (nome, idade)) #mais antiga
print('Nome: {0}, Idade: {1}'.format(nome, idade)) #python < 3.6
nome = "Rafael"
idade = 20
print(f'Nome: {nome}, Idade:{idade}') #python >= 3.6
# Out:
# Nome: Giovana, Idade:30.99
# Nome: Giovana, Idade: 30.9875
# Nome: Rafael, Idade:20
